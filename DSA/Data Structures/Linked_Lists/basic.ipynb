# %%
class Node:
    def __init__(self, data = None, next = None):
        self.data = data
        self.next = next

# %%
class Linked_List():
    def __init__(self):
        self.head = None

    def insert_at_beginning(self, data):
        node = Node(data, self.head)
        self.head = node

    def print(self):
        if self.head is None:
            print("Linked List is empty")
            return

        itr = self.head
        llstr = ''
        while itr:
            llstr += str(itr.data) + '-->'
            itr = itr.next

        print(llstr)

    def insert_at_end(self,data):
        node = Node(data)

        if self.head is None:
            self.head = node       
            return
    
        itr = self.head
        while itr.next:
            itr = itr.next

        itr.next = node

    def insert_values(self, data_values):
        for value in data_values:
            self.insert_at_end(value)
            
    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count += 1
            itr = itr.next
        return count   
    
    def remove_at(self, index):
        if self.get_length() <= index or index < 0:
            raise Exception("Invalid Index")
        
        elif index == 0:
            self.head = self.head.next

        else:
            itr = self.head
            count = 0
            while itr:
                if count + 1 == index:
                    itr.next = itr.next.next
                    break

                itr = itr.next
                count += 1
                
    def insert_at(self, index, value):
        new_node = Node(value)
        if index < 0 or index > self.get_length():
            raise Exception("Invalid Index")
        
        elif index == 0:
            new_node.next = self.head
            self.head = new_node
        
        else:
            count = 0
            itr = self.head
            while itr:
                if count + 1 == index:
                  new_node.next = itr.next
                  itr.next = new_node
                  break

                itr = itr.next 
                count += 1

    def reverse_ll(self):
        head = self.head
        prev, curr = None, head
        while curr:
            next = curr.next
            curr.next = prev
            prev = curr
            curr = next
        self.head = prev

    def reverse_recursion_ll(self, prev = None):
        curr = self.head
        nxt = curr.next
        curr.next = prev

        if nxt:
            self.head = nxt
            self.reverse_recursion_ll(curr)

# %%
ll = Linked_List()
ll.insert_at_beginning(5)
ll.insert_at_beginning(89)
ll.print()
# Out:
# 89-->5-->

# %%
ll = Linked_List()
ll.insert_at_end(5)
ll.insert_at_end(89)
ll.print()
# Out:
# 5-->89-->

# %%
ll = Linked_List()
ll.insert_at_beginning(5)
ll.insert_at_beginning(89)
ll.insert_at_end(79)
ll.print()
# Out:
# 89-->5-->79-->

# %%
ll = Linked_List()
ll.insert_values(['apples', 'oranges', 'bananas'])
len_of_ll = ll.get_length()
ll.print()
print(f"Length of the Linked List is {len_of_ll}")
# Out:
# apples-->oranges-->bananas-->
# Length of the Linked List is 3

# %%
ll = Linked_List()
ll.insert_values(['apples', 'oranges', 'bananas'])
len_of_ll = ll.get_length()
ll.print()
print(f"Length of the Linked List is {len_of_ll}")
ll.remove_at(1)
len_of_ll = ll.get_length()
ll.print()
print(f"Length of the Linked List is {len_of_ll}")
# Out:
# apples-->oranges-->bananas-->
# Length of the Linked List is 3
# apples-->bananas-->
# Length of the Linked List is 2

# %%
ll = Linked_List()
ll.insert_values(['apples', 'oranges', 'bananas'])
len_of_ll = ll.get_length()
ll.print()
print(f"Length of the Linked List is {len_of_ll}")
ll.insert_at(1, "figs")
len_of_ll = ll.get_length()
ll.print()
print(f"Length of the Linked List is {len_of_ll}")
# Out:
# apples-->oranges-->bananas-->
# Length of the Linked List is 3
# apples-->figs-->oranges-->bananas-->
# Length of the Linked List is 4

# %%
ll = Linked_List()
ll.insert_values(['apples', 'oranges', 'bananas'])
ll.insert_at(0,"grapes")
ll.print()
# Out:
# grapes-->apples-->oranges-->bananas-->

# %% [markdown]
# In-place Iterative Reverse Linked List

# %%
ll = Linked_List()
ll.insert_values([1,2,3,4,5])
ll.print()
# Out:
# 1-->2-->3-->4-->5-->

# %%
ll.reverse_ll()
ll.print()
# Out:
# 5-->4-->3-->2-->1-->

# %% [markdown]
# In-Place Recursive Reverse Linked List

# %%
ll = Linked_List()
ll.insert_values([1,2,3,4,5])
ll.print()
# Out:
# 1-->2-->3-->4-->5-->

# %%
ll.reverse_recursion_ll()
ll.print()
# Out:
# 5-->4-->3-->2-->1-->
