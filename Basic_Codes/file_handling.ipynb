# %%
f1 = open("file_1.txt", "w") #write mode (create or overwrite file)
f1.write("File handling basic understanding.")
# Out:
# 34

# %%
f1 = open("file_1.txt", "r") #only read
data = f1.read()
print(data)
# Out:
# File handling basic understanding.
